# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pylab as pl
# %matplotlib inline

# %%
os.chdir("C:\\Users\\amite\\OneDrive\\Desktop\\New folder")

# %%
df=pd.read_csv("C:\\Users\\amite\\OneDrive\\Desktop\\New folder\\50_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
sns.pairplot(data=df,kind='reg',corner=True)

# %%
sns.heatmap(df.corr(),annot=True,linewidth=0.2)
# Out:
# <AxesSubplot:>

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
df['State']=le.fit_transform(df['State'])
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      2  192261.83
# 1  162597.70       151377.59        443898.53      0  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      2  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %%
X=df[['R&D Spend','Administration','Administration','State']]
y=df['Profit']

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X)
y_pred
# Out:
# array([190159.98862405, 187073.87974279, 181815.48315469, 173040.51620026,
#        172560.51161683, 163266.81191733, 163169.91434995, 159509.25655249,
#        150902.38189857, 155485.93761755, 136888.34436712, 136841.84254174,
#        129061.84119681, 127041.93581013, 149997.57859486, 147096.64519313,
#        115726.07469243, 128777.8016749 , 127935.45718476, 121228.5114226 ,
#        114619.05724158, 114291.33701696, 112171.73413647, 107503.15948155,
#        116019.77544499, 103265.70541142, 112190.26940184, 110248.64140036,
#        102150.33856981, 103308.65366795, 102204.16418792,  99473.02647388,
#        102730.69742615,  97266.62516214,  86579.30048164,  90021.12294893,
#         72862.3258702 ,  90188.42422107,  68802.94906477,  83756.36059169,
#         73418.35045846,  74442.32903055,  70194.77064014,  61473.73257033,
#         65826.17404768,  49138.68905103,  49879.22121991,  47732.40899544,
#         52581.88056597,  48710.02086614])

# %%
from sklearn.metrics import r2_score
print('r2score',r2_score(y,y_pred))
# Out:
# r2score 0.9478132427746071

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=2)
X_poly=poly_reg.fit_transform(X)
reg.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
ypred1=reg.predict(X_poly)
print(r2_score(y,ypred1))
# Out:
# 0.9539207088334535
